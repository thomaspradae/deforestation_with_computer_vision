# %% [markdown]
# # (1) - Conseguir data
# Este es el codigo que fue empleado para conseguir la data trabajada

# %%
import rasterio

file_path = '/workspaces/codespaces-jupyter/data/Hansen_GFC-2023-v1.11_lossyear_10N_080W.tif'

with rasterio.open(file_path) as dataset:
    crs = dataset.crs
    transform = dataset.transform
    bounds = dataset.bounds

    print("Coordinate Reference System (CRS):", crs)
    print("Affine Transform:", transform)
    print("Bounds:", bounds)

    if crs and not transform.is_identity:
        print("The TIFF file is georeferenced.")
    else:
        print("The TIFF file is NOT georeferenced.")
# Out:
# Coordinate Reference System (CRS): EPSG:4326
# Affine Transform: | 0.00, 0.00,-80.00|
# | 0.00,-0.00, 10.00|
# | 0.00, 0.00, 1.00|
# Bounds: BoundingBox(left=-80.0, bottom=0.0, right=-70.0, top=10.0)
# The TIFF file is georeferenced.

# %%
import rasterio

file_path = '/workspaces/codespaces-jupyter/data/Hansen_GFC-2023-v1.11_lossyear_10N_080W.tif'

dataset = rasterio.open(file_path)

# %%
import ee
import time
import logging

ee.Initialize()

# Configurar el registro de logs
logging.basicConfig(
    level=logging.INFO,  # Cambiar a logging.DEBUG para más detalles
    format='%(asctime)s - %(levelname)s - %(message)s',
)

# Cargar la imagen 'lossyear'
lossyear = ee.Image('projects/ee-thomaspradaes/assets/colombia')

# Crear máscaras
loss2023 = lossyear.eq(23).selfMask().rename('constant')
noLoss = lossyear.eq(0).selfMask().rename('constant')

# Número de muestras
num_samples = 500

# Verificar nombres de bandas
print('Band names of lossyear:', lossyear.bandNames().getInfo())
print('Band names of loss2023:', loss2023.bandNames().getInfo())
print('Band names of noLoss:', noLoss.bandNames().getInfo())

# Muestreo de puntos
logging.info('Sampling points where deforestation occurred in 2023.')
loss_points = loss2023.stratifiedSample(
    numPoints=num_samples,
    classBand='constant',
    region=lossyear.geometry(),
    scale=30,
    seed=42,
    geometries=True
).map(lambda f: f.set('label', 1))

logging.info('Sampling points where no deforestation occurred.')
no_loss_points = noLoss.stratifiedSample(
    numPoints=num_samples,
    classBand='constant',
    region=lossyear.geometry(),
    scale=30,
    seed=84,
    geometries=True
).map(lambda f: f.set('label', 0))

# Combinar puntos
all_points = loss_points.merge(no_loss_points)
logging.info(f'Total number of points sampled: {all_points.size().getInfo()}')

# Función para extraer parches de imágenes
def extract_image_patch(feature):
    half_size = 5000
    point = feature.geometry()
    point_proj = point.transform('EPSG:3857', 1)
    coords = point_proj.coordinates()
    x = coords.get(0)
    y = coords.get(1)
    square = ee.Geometry.Rectangle([
        ee.Number(x).subtract(half_size),
        ee.Number(y).subtract(half_size),
        ee.Number(x).add(half_size),
        ee.Number(y).add(half_size)
    ], 'EPSG:3857', False)
    landsat8 = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2') \
        .filterBounds(square) \
        .filterDate('2023-01-01', '2023-12-31') \
        .filter(ee.Filter.lt('CLOUD_COVER', 20)) \
        .map(lambda image: image \
             .select(['SR_B4', 'SR_B3', 'SR_B2']) \
             .multiply(0.0000275).add(-0.2) \
             .set('system:time_start', image.get('system:time_start'))) \
        .median() \
        .clip(square)
    return feature.set({'image': landsat8, 'square': square})

# Aplicar la función sobre todos los puntos
logging.info('Extracting image patches around sampled points.')
labeled_points = all_points.map(extract_image_patch)

# Gestión de tareas
MAX_ACTIVE_TASKS = 10

def get_num_active_tasks():
    task_list = ee.data.getTaskList()
    active_tasks = [task for task in task_list if task['state'] in ['READY', 'RUNNING']]
    return len(active_tasks)

# Exportar imágenes a Google Drive
points_list = labeled_points.toList(labeled_points.size())
total_samples = num_samples * 2

logging.info('Starting export of images to Google Drive.')
for i in range(total_samples):
    feature = ee.Feature(points_list.get(i))
    label = feature.get('label').getInfo()
    image = ee.Image(feature.get('image'))
    square = ee.Geometry(feature.get('square'))
    description = 'Deforestation_Image_{}'.format(i)
    fileNamePrefix = 'deforestation_{}_{}'.format(int(label), i)
    task = ee.batch.Export.image.toDrive(
        image=image,
        description=description,
        folder='EarthEngineImages',  # Opcional: especificar una carpeta en Google Drive
        fileNamePrefix=fileNamePrefix,
        scale=30,
        region=square,
        maxPixels=1e9
    )
    task.start()
    logging.info(f'Started export task {task.id} for image {i} with label {label}.')

    # Esperar si se alcanzan el máximo de tareas activas
    while get_num_active_tasks() >= MAX_ACTIVE_TASKS:
        logging.info('Maximum active tasks reached. Waiting before starting new tasks...')
        time.sleep(30)

logging.info('All export tasks have been submitted.')
# Out:
# Band names of lossyear: ['b1']
# 2024-09-26 05:28:22,453 - INFO - Sampling points where deforestation occurred in 2023.
# 2024-09-26 05:28:22,454 - INFO - Sampling points where no deforestation occurred.
# Band names of loss2023: ['constant']
# Band names of noLoss: ['constant']
# 2024-09-26 05:28:47,697 - INFO - Total number of points sampled: 1000
# 2024-09-26 05:28:47,698 - INFO - Extracting image patches around sampled points.
# 2024-09-26 05:28:47,704 - INFO - Starting export of images to Google Drive.
# 2024-09-26 05:28:50,822 - INFO - Started export task 6PIGASIBG56DZ2ZY42675QCD for image 0 with label 1.
# 2024-09-26 05:28:53,989 - INFO - Started export task CZBZ7OUAKD5EV3VDZ4LJKBYC for image 1 with label 1.
# 2024-09-26 05:28:56,581 - INFO - Started export task YUIAGA7ZWJSDIJKIJTSAPRLF for image 2 with label 1.
# 2024-09-26 05:28:59,666 - INFO - Started export task IAHPRSB62CUEBBT7WHPT77TE for image 3 with label 1.
# 2024-09-26 05:29:03,900 - INFO - Started export task SAMQPCPLBJHFNMDFRMWOMHLG for image 4 with label 1.
# 2024-09-26 05:29:07,438 - INFO - Started export task XHTHDL3EEL2YQM5KGDEEHAQI for image 5 with label 1.
# 2024-09-26 05:29:10,954 - INFO - Started export task TKMR4KQPJDCPW7BB5UR4RLRH for image 6 with label 1.
# 2024-09-26 05:29:14,514 - INFO - Started export task NV6BS5DWTSJJUT4B726LCPLM for image 7 with label 1.
# 2024-09-26 05:29:17,923 - INFO - Started export task GFKFYCB6BLTD6UZAFJVYDIRU for image 8 with label 1.
# 2024-09-26 05:29:20,930 - INFO - Started export task LLZWDPQ5EM6IA7MFFN2DD77U for image 9 with label 1.
# 2024-09-26 05:29:24,227 - INFO - Started export task RHYOHVHY6EBLLPFHT6HUDGVP for image 10 with label 1.
# 2024-09-26 05:29:27,584 - INFO - Started export task J2MXO753OGHK6RYADTAGUFFZ for image 11 with label 1.
# 2024-09-26 05:29:30,554 - INFO - Started export task FZ6PXPGDIHNVK4LRKSVEDORN for image 12 with label 1.
# 2024-09-26 05:29:34,695 - INFO - Started export task LI7EZYOYIHRDCOBXHV4S5WY4 for image 13 with label 1.
# 2024-09-26 05:29:38,962 - INFO - Started export task NILBSS5OEF5HS6RD5ADI53UC for image 14 with label 1.
# 2024-09-26 05:29:39,146 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:30:12,350 - INFO - Started export task XCU2LU2IVO3H2C6WX6MPI5WM for image 15 with label 1.
# 2024-09-26 05:30:15,086 - INFO - Started export task YZHRGYSZDZPF3CH4VODT2NOO for image 16 with label 1.
# 2024-09-26 05:30:18,138 - INFO - Started export task I7QZJSGW5CFRMXMKTXAGVJWR for image 17 with label 1.
# 2024-09-26 05:30:21,882 - INFO - Started export task ESZ7IPXGCWQXQ7UPOYN677M7 for image 18 with label 1.
# 2024-09-26 05:30:24,854 - INFO - Started export task PQSDHBI3XRK6ODVNCZ3A6CV4 for image 19 with label 1.
# 2024-09-26 05:30:28,499 - INFO - Started export task KMBCQSOPPA3LBBPAKHQOGOGO for image 20 with label 1.
# 2024-09-26 05:30:31,924 - INFO - Started export task PV6N5VABULC4QGHDKGIAQYKO for image 21 with label 1.
# 2024-09-26 05:30:35,656 - INFO - Started export task IEVVTPVDTIRWJ253EKADEBEP for image 22 with label 1.
# 2024-09-26 05:30:39,392 - INFO - Started export task ZL6DBEAIYLPNWDHCWOSR2OHR for image 23 with label 1.
# 2024-09-26 05:30:42,543 - INFO - Started export task MAQFNAXMQ7J2TDHUCUNGZF5J for image 24 with label 1.
# 2024-09-26 05:30:42,724 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:31:16,107 - INFO - Started export task 3ZYJRXBIYZ2EXUXRQMQRLQ3K for image 25 with label 1.
# 2024-09-26 05:31:19,463 - INFO - Started export task HF4PKCDRSXYUCSC37JB65M2T for image 26 with label 1.
# 2024-09-26 05:31:23,532 - INFO - Started export task X3YZRDSGMDJDMVN5Y4GQK6T4 for image 27 with label 1.
# 2024-09-26 05:31:26,499 - INFO - Started export task H3ZOOQIUBWH5YPFNZG7GTQ33 for image 28 with label 1.
# 2024-09-26 05:31:29,484 - INFO - Started export task Q2YDKEBWTQWYFGG4WIJ47OXR for image 29 with label 1.
# 2024-09-26 05:31:29,779 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:32:02,942 - INFO - Started export task YBG45YJYVTLE6SVB4GQRYHEM for image 30 with label 1.
# 2024-09-26 05:32:06,176 - INFO - Started export task MYQAWIN5M26NJWMOXN7XJX4I for image 31 with label 1.
# 2024-09-26 05:32:09,573 - INFO - Started export task T6PDSGCQULWXEXP4QOUPMMCA for image 32 with label 1.
# 2024-09-26 05:32:13,146 - INFO - Started export task FVCLPRXVSWOXRXLAWCHIY422 for image 33 with label 1.
# 2024-09-26 05:32:15,967 - INFO - Started export task PECDILCTN6NMRZJNYH4BEESM for image 34 with label 1.
# 2024-09-26 05:32:19,398 - INFO - Started export task XBX6OPO6A6YT3UN6GGJ56TWF for image 35 with label 1.
# 2024-09-26 05:32:19,655 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:32:53,587 - INFO - Started export task ZUQEKUQWBU3LS7TAWDNZPWW2 for image 36 with label 1.
# 2024-09-26 05:32:56,771 - INFO - Started export task P22JNZ5NS3BXMFZNKXSYRKV6 for image 37 with label 1.
# 2024-09-26 05:33:00,285 - INFO - Started export task IMH5K2DTES6ZLI3BIYTWTXNX for image 38 with label 1.
# 2024-09-26 05:33:03,616 - INFO - Started export task VBWFIHHI5HDSFN4MCM3YFBGL for image 39 with label 1.
# 2024-09-26 05:33:06,846 - INFO - Started export task DJTVREAEQJVEOW63FCVAQCE3 for image 40 with label 1.
# 2024-09-26 05:33:10,708 - INFO - Started export task G22WCT6EK5YOYDAGM4FX2EDL for image 41 with label 1.
# 2024-09-26 05:33:11,433 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:33:45,135 - INFO - Started export task L77IWHTHQP72WZ5HE64DKQTY for image 42 with label 1.
# 2024-09-26 05:33:48,267 - INFO - Started export task Q52N3VGLQLEKRFSQHHUEVW4X for image 43 with label 1.
# 2024-09-26 05:33:50,847 - INFO - Started export task T7VXHN6X3JJFW4KXCLPTJ5PU for image 44 with label 1.
# 2024-09-26 05:33:53,578 - INFO - Started export task 3MBAHWJ23VLPVQI2K6S722CC for image 45 with label 1.
# 2024-09-26 05:33:57,014 - INFO - Started export task LSZF5HGY5OVC4OLSDILLM75V for image 46 with label 1.
# 2024-09-26 05:34:00,068 - INFO - Started export task VSTVMDLBTP2LN2WCG7IGGJLZ for image 47 with label 1.
# 2024-09-26 05:34:03,537 - INFO - Started export task ZCU3UZ6W66FA4HNE5VOVF2FI for image 48 with label 1.
# 2024-09-26 05:34:03,798 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:34:37,046 - INFO - Started export task XNVDTZXN2NKZHTGXTWSLM7G6 for image 49 with label 1.
# 2024-09-26 05:34:40,298 - INFO - Started export task 4TXHE6MSOFFZSBQ3TZDBPONS for image 50 with label 1.
# 2024-09-26 05:34:43,772 - INFO - Started export task KJE36GH5VYYAKF2O6DZMRQYR for image 51 with label 1.
# 2024-09-26 05:34:46,874 - INFO - Started export task FJQ6DIYCCMPCOXZ756VMXCS3 for image 52 with label 1.
# 2024-09-26 05:34:49,994 - INFO - Started export task RBGIE2AG3NX4CFHOCCWJNDZD for image 53 with label 1.
# 2024-09-26 05:34:53,144 - INFO - Started export task WILOHS3HLEO23B3RS5S2HSHT for image 54 with label 1.
# 2024-09-26 05:34:53,521 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:35:26,601 - INFO - Started export task L63TJPFVYUETOXC3JQUR3EFB for image 55 with label 1.
# 2024-09-26 05:35:29,451 - INFO - Started export task 6RULYJG5THHUH4KJ6QGV3VNY for image 56 with label 1.
# 2024-09-26 05:35:32,991 - INFO - Started export task WJ2MZMIBDYQIELFZDMBXIPES for image 57 with label 1.
# 2024-09-26 05:35:36,905 - INFO - Started export task J2CFYYXR733TURY22H2XLUDG for image 58 with label 1.
# 2024-09-26 05:35:40,011 - INFO - Started export task YML2VYP4AFSFV77CT45DPWRV for image 59 with label 1.
# 2024-09-26 05:35:43,530 - INFO - Started export task XDKHIAGKXZRFTP3SHTLUYJFJ for image 60 with label 1.
# 2024-09-26 05:35:47,008 - INFO - Started export task CSM6ZZZWIVBWCVYGQQQG7UUP for image 61 with label 1.
# 2024-09-26 05:35:50,217 - INFO - Started export task QN3GZXIKBCCYGCWJA4EKVYF6 for image 62 with label 1.
# 2024-09-26 05:35:53,277 - INFO - Started export task 6QLSULVGKHBZ2NYGR7G5GIYD for image 63 with label 1.
# 2024-09-26 05:35:53,464 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:36:26,660 - INFO - Started export task MPBYNQ4U6JI7FAWBTCX3FRSC for image 64 with label 1.
# 2024-09-26 05:36:30,463 - INFO - Started export task SH3VWWEVDWT76YAVYOJJT57P for image 65 with label 1.
# 2024-09-26 05:36:34,418 - INFO - Started export task CTCTCP4QD5AYPXSZK4FZH6IW for image 66 with label 1.
# 2024-09-26 05:36:37,792 - INFO - Started export task O4YDM6RSBMN4Z4DCXQH7KD4U for image 67 with label 1.
# 2024-09-26 05:36:40,185 - INFO - Started export task U2YA3HQ2VFNDNC5TOBJALWQX for image 68 with label 1.
# 2024-09-26 05:36:42,569 - INFO - Started export task GESL7VK3JGM6LALBUGIVY6TE for image 69 with label 1.
# 2024-09-26 05:36:45,746 - INFO - Started export task XGN6OPTO4XK2W2MMEAZYEYBP for image 70 with label 1.
# 2024-09-26 05:36:46,156 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:37:18,849 - INFO - Started export task IJVEC7RFUA2JHPWJMWUIOPS6 for image 71 with label 1.
# 2024-09-26 05:37:22,112 - INFO - Started export task J52I5NR5FYWOXAK62M6H3QS7 for image 72 with label 1.
# 2024-09-26 05:37:24,871 - INFO - Started export task E3CLMLZS4CTPZFBAEZPMSKHL for image 73 with label 1.
# 2024-09-26 05:37:27,998 - INFO - Started export task GJBDE4HH6HSFCOCRZOOX3GIF for image 74 with label 1.
# 2024-09-26 05:37:31,156 - INFO - Started export task CJ47GRQDEOCTPLPKSFLD7KQC for image 75 with label 1.
# 2024-09-26 05:37:34,464 - INFO - Started export task Q2D23KOYYMC4SQPXVN3EY7VL for image 76 with label 1.
# 2024-09-26 05:37:37,850 - INFO - Started export task 5YLYGSHZA4LRBAVD62RLINAR for image 77 with label 1.
# 2024-09-26 05:37:38,058 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:38:11,163 - INFO - Started export task 3OX7J7U6CPSHYZY76CMV3XEO for image 78 with label 1.
# 2024-09-26 05:38:14,355 - INFO - Started export task QJJJ7WHAYMCOOV3WSIGULLOB for image 79 with label 1.
# 2024-09-26 05:38:17,800 - INFO - Started export task OHSZRKVKMYKD7WOEEV3BSU2C for image 80 with label 1.
# 2024-09-26 05:38:20,834 - INFO - Started export task YYXM672KR7B4LL5MCEPK6OVK for image 81 with label 1.
# 2024-09-26 05:38:24,525 - INFO - Started export task 6ACPCGUZVCYQOZLFX6IOGWJW for image 82 with label 1.
# 2024-09-26 05:38:27,810 - INFO - Started export task NV2JDTCL66RNH3SERWGFZPNS for image 83 with label 1.
# 2024-09-26 05:38:30,832 - INFO - Started export task 7SJHZPJ4WSCGIO6WJGYXWWSY for image 84 with label 1.
# 2024-09-26 05:38:31,190 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:39:04,344 - INFO - Started export task 3KMHCWK2GDKMVAO46XSCMVJH for image 85 with label 1.
# 2024-09-26 05:39:07,311 - INFO - Started export task ZDLNY2R5DBNBS3ZBY2WIS6YB for image 86 with label 1.
# 2024-09-26 05:39:10,495 - INFO - Started export task U2RNZS7P5TPJY7WTJKDJQ3KF for image 87 with label 1.
# 2024-09-26 05:39:14,340 - INFO - Started export task VWLBHEESY7N5TYFIYMCCYNPB for image 88 with label 1.
# 2024-09-26 05:39:17,342 - INFO - Started export task XQWVHH2KPYIDDUWFHXS4FRE4 for image 89 with label 1.
# 2024-09-26 05:39:20,776 - INFO - Started export task NJND35YXLK3XZIE5NDAFVJDB for image 90 with label 1.
# 2024-09-26 05:39:21,163 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:39:54,645 - INFO - Started export task ZPQYTEFDYDGW3RLJLBHP4GRV for image 91 with label 1.
# 2024-09-26 05:39:57,790 - INFO - Started export task WE727YJCWWHIVVM7EUUVFANR for image 92 with label 1.
# 2024-09-26 05:40:00,882 - INFO - Started export task OAT3RB6MGEBVGG4JCYSVV7UI for image 93 with label 1.
# 2024-09-26 05:40:04,153 - INFO - Started export task IZLLRB2GM6PYNLBD22P7AUQ2 for image 94 with label 1.
# 2024-09-26 05:40:07,206 - INFO - Started export task PPLRDHCLIUITVOMHZSFPMTVZ for image 95 with label 1.
# 2024-09-26 05:40:10,813 - INFO - Started export task BU745YS2CB2ZLAUWDLMS36G6 for image 96 with label 1.
# 2024-09-26 05:40:10,994 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:40:44,431 - INFO - Started export task XOXP4WBJJN2TC3SZHAQXPBBG for image 97 with label 1.
# 2024-09-26 05:40:47,714 - INFO - Started export task QCBXMWOC4Z3G5LXKK3IHM4LQ for image 98 with label 1.
# 2024-09-26 05:40:51,194 - INFO - Started export task SZQIS6IQE7PGCQD6A57K6ASL for image 99 with label 1.
# 2024-09-26 05:40:54,799 - INFO - Started export task J26Q6IW77CYON4GSYGWAVIZF for image 100 with label 1.
# 2024-09-26 05:40:58,134 - INFO - Started export task 54RJORWNGA7QCSGLO427R235 for image 101 with label 1.
# 2024-09-26 05:41:01,349 - INFO - Started export task 6VAYDLDJU62VAMY5COQO67L2 for image 102 with label 1.
# 2024-09-26 05:41:01,767 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:41:35,050 - INFO - Started export task WEQ67XDDAQXQ2ZBFFMAG6MEU for image 103 with label 1.
# 2024-09-26 05:41:38,316 - INFO - Started export task 5RFP7VYZXYXJ55CGESE5UCTL for image 104 with label 1.
# 2024-09-26 05:41:41,383 - INFO - Started export task AWCZKQLXCST73MKUEVH3SNPI for image 105 with label 1.
# 2024-09-26 05:41:43,365 - INFO - Started export task O2FVLN6GG6R7MLJG5R5EEJRS for image 106 with label 1.
# 2024-09-26 05:41:46,445 - INFO - Started export task JP23CDHH5MDSJ5GQQMILOVC4 for image 107 with label 1.
# 2024-09-26 05:41:49,484 - INFO - Started export task 2Y374M5EFXZ3FE2DFBJM7WJV for image 108 with label 1.
# 2024-09-26 05:41:52,463 - INFO - Started export task VTMO77ISMFN6KYYSUVUKBJTX for image 109 with label 1.
# 2024-09-26 05:41:55,989 - INFO - Started export task VVUEFDOOKN22MM5SN2OFAWMT for image 110 with label 1.
# 2024-09-26 05:41:56,344 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:42:29,787 - INFO - Started export task 2IZJVF6UAXLC4XMU72M26B5H for image 111 with label 1.
# 2024-09-26 05:42:33,059 - INFO - Started export task LTXKSKNF7OPQFL2O6GCNFT7J for image 112 with label 1.
# 2024-09-26 05:42:36,585 - INFO - Started export task VGI72AF2QK62DGNIKKL46Z2Q for image 113 with label 1.
# 2024-09-26 05:42:39,828 - INFO - Started export task PZL77DW6B3MOJOWQN62HTBZP for image 114 with label 1.
# 2024-09-26 05:42:43,145 - INFO - Started export task RR3UMVEMOCBT6QVNPMDBJXRC for image 115 with label 1.
# 2024-09-26 05:42:43,345 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:43:16,393 - INFO - Started export task TCVDGXLZ6GPVUMKUAFRSPM4O for image 116 with label 1.
# 2024-09-26 05:43:19,394 - INFO - Started export task YF7JSYBQVQ5VABBD6JAXNMYV for image 117 with label 1.
# 2024-09-26 05:43:22,794 - INFO - Started export task FPYIKIJLZUQ7EL7NRIPUKIXR for image 118 with label 1.
# 2024-09-26 05:43:25,738 - INFO - Started export task 3LLBYLF74MHRDHL3XUDEDY2L for image 119 with label 1.
# 2024-09-26 05:43:29,083 - INFO - Started export task D3LV2QTYKI456J2PASPVHETG for image 120 with label 1.
# 2024-09-26 05:43:31,935 - INFO - Started export task C7CGOV4ML6COP6F4VD3PWAN4 for image 121 with label 1.
# 2024-09-26 05:43:35,108 - INFO - Started export task DPEBR747TELN4MO2TXM3AHVB for image 122 with label 1.
# 2024-09-26 05:43:38,239 - INFO - Started export task 4HWIOQIT5IPOFXQLRXYP5GNY for image 123 with label 1.
# 2024-09-26 05:43:38,607 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:44:12,359 - INFO - Started export task OVPVEJDS6BXBM35OHGDOEG2W for image 124 with label 1.
# 2024-09-26 05:44:15,847 - INFO - Started export task EPMPKMFPUZ7AWXQK63QUQJBJ for image 125 with label 1.
# 2024-09-26 05:44:18,706 - INFO - Started export task 3WDTTL7UECBPLCFEWBC7HLIS for image 126 with label 1.
# 2024-09-26 05:44:21,113 - INFO - Started export task EQKFWGO7BEUP4627JSSWULOV for image 127 with label 1.
# 2024-09-26 05:44:23,941 - INFO - Started export task IHANGC5OIXPVDLP7NA7SGDU7 for image 128 with label 1.
# 2024-09-26 05:44:26,679 - INFO - Started export task P4M4Y2OFIWVAJKCJC6GCHNDM for image 129 with label 1.
# 2024-09-26 05:44:29,588 - INFO - Started export task RCIT7J3C2VUESQS6KQI2L5JK for image 130 with label 1.
# 2024-09-26 05:44:32,767 - INFO - Started export task XDZFWHXUWXCYGWVMLMRZP4C4 for image 131 with label 1.
# 2024-09-26 05:44:35,956 - INFO - Started export task TL2UZRRTWO73QZ7GBRO3V4NL for image 132 with label 1.
# 2024-09-26 05:44:39,370 - INFO - Started export task IKBFJKR64HC67S4XNU7ME5NV for image 133 with label 1.
# 2024-09-26 05:44:39,703 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:45:12,546 - INFO - Started export task GDEILXIMXZPC4544RGMU2RQA for image 134 with label 1.
# 2024-09-26 05:45:16,548 - INFO - Started export task LJSXPGEMRWFF7KOKAT4GHWIR for image 135 with label 1.
# 2024-09-26 05:45:20,640 - INFO - Started export task EFGE4VZ2Y7UFYPSZYE3SCMK5 for image 136 with label 1.
# 2024-09-26 05:45:20,805 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:45:54,531 - INFO - Started export task FJZK73XHEIKXHOJ6SCJT4HLG for image 137 with label 1.
# 2024-09-26 05:45:57,978 - INFO - Started export task 23ACHD2PFEMBCHGUQFA4CACW for image 138 with label 1.
# 2024-09-26 05:46:00,742 - INFO - Started export task H77WVTRWCCS6JICXU2MXYRKB for image 139 with label 1.
# 2024-09-26 05:46:02,976 - INFO - Started export task K6FZPIC3Q4HAUG7RNGK2ZWSV for image 140 with label 1.
# 2024-09-26 05:46:06,356 - INFO - Started export task NZ2XT7PSIZM6VUU7CXDEDVU7 for image 141 with label 1.
# 2024-09-26 05:46:09,366 - INFO - Started export task FVM2GF6MAHVPFPN47XQM7FZQ for image 142 with label 1.
# 2024-09-26 05:46:09,647 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:46:43,018 - INFO - Started export task 4DYN6EDJ44NMGON5LULE4REC for image 143 with label 1.
# 2024-09-26 05:46:46,240 - INFO - Started export task HSMLB5UCK3YOF66YL45TGFPG for image 144 with label 1.
# 2024-09-26 05:46:49,444 - INFO - Started export task UGG2VAOWTSA57HEMA6H54TYP for image 145 with label 1.
# 2024-09-26 05:46:52,458 - INFO - Started export task 5SPTMI3L3FQT4JR2WTSHX6S7 for image 146 with label 1.
# 2024-09-26 05:46:55,382 - INFO - Started export task PQWDLUJQ6WZ6ZKBWSJOH23EP for image 147 with label 1.
# 2024-09-26 05:46:58,289 - INFO - Started export task W4QM55KLTJ5PTFPSRZLTTF4E for image 148 with label 1.
# 2024-09-26 05:46:58,456 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:47:31,621 - INFO - Started export task ZMD54WUL2ZW63IDND2YZQNPL for image 149 with label 1.
# 2024-09-26 05:47:35,434 - INFO - Started export task YIWAXRL4MMOQQXQ7ONLUGKA7 for image 150 with label 1.
# 2024-09-26 05:47:40,033 - INFO - Started export task XVVS2XXL5A4FTUQDMRFH4GA4 for image 151 with label 1.
# 2024-09-26 05:47:40,221 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:48:13,091 - INFO - Started export task JMCLJ4DQVOWEI7QSH2LTJ73I for image 152 with label 1.
# 2024-09-26 05:48:16,185 - INFO - Started export task WHNHX7B5AMEHBNKLKQPMJSAC for image 153 with label 1.
# 2024-09-26 05:48:19,993 - INFO - Started export task S4M7WJCMCT3DD4OYXRIKYQBS for image 154 with label 1.
# 2024-09-26 05:48:22,927 - INFO - Started export task 2U3I2HNW4MPYRIGQXX6PWR7Z for image 155 with label 1.
# 2024-09-26 05:48:26,087 - INFO - Started export task FRDIKGWJYLXMTGBMJEGMPKXL for image 156 with label 1.
# 2024-09-26 05:48:28,991 - INFO - Started export task 2UGZLXSHZD47BBGHF65YDKXW for image 157 with label 1.
# 2024-09-26 05:48:29,139 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:49:03,023 - INFO - Started export task KKSJNJ5ESZ5JVVSK2A6VSMQF for image 158 with label 1.
# 2024-09-26 05:49:06,806 - INFO - Started export task VEZ2UAW6KGUOD4VO6SANSV5I for image 159 with label 1.
# 2024-09-26 05:49:11,257 - INFO - Started export task JOA6WDSIIF7MRHW27YDHHDZQ for image 160 with label 1.
# 2024-09-26 05:49:14,334 - INFO - Started export task POEA54HT27QGB7W3ONBANXXN for image 161 with label 1.
# 2024-09-26 05:49:17,833 - INFO - Started export task TZNZQCXVB3WEZNIZR2QVBCVC for image 162 with label 1.
# 2024-09-26 05:49:19,943 - INFO - Started export task 73SGJATNQ52UUVPIF5UOWRQQ for image 163 with label 1.
# 2024-09-26 05:49:23,088 - INFO - Started export task 7CZ6SPFUWJYUPOZQSGAUH2X3 for image 164 with label 1.
# 2024-09-26 05:49:23,419 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:49:56,795 - INFO - Started export task F7QPJTGRKKR6UM3CU5WQJNFE for image 165 with label 1.
# 2024-09-26 05:49:59,960 - INFO - Started export task 3K3SN4GKQ4NRFGKX5P65UETC for image 166 with label 1.
# 2024-09-26 05:50:02,942 - INFO - Started export task ANZCQDVW6TRZSFYGXJYXV6GJ for image 167 with label 1.
# 2024-09-26 05:50:06,365 - INFO - Started export task DODOSADEOI5RLA7GC5XTVUWX for image 168 with label 1.
# 2024-09-26 05:50:08,409 - INFO - Started export task UIYJXKHU4ZG3ZQDSGQUOVZVX for image 169 with label 1.
# 2024-09-26 05:50:11,899 - INFO - Started export task LMP6DJ3O3FTZNPQUJN2PCMGR for image 170 with label 1.
# 2024-09-26 05:50:14,886 - INFO - Started export task GSF7PVWZM7PIF4Y2K3B44J6Q for image 171 with label 1.
# 2024-09-26 05:50:17,834 - INFO - Started export task CY4XJTJXVKLI4CKQNR27HB2D for image 172 with label 1.
# 2024-09-26 05:50:21,697 - INFO - Started export task 5ZYA2ACTODVV6XIF6LZC7H72 for image 173 with label 1.
# 2024-09-26 05:50:25,191 - INFO - Started export task T2J27ACJZYNWRVII3CS2RGCA for image 174 with label 1.
# 2024-09-26 05:50:25,471 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:50:58,562 - INFO - Started export task U2BHHVBSCSNBWY5EYW3363JU for image 175 with label 1.
# 2024-09-26 05:51:02,021 - INFO - Started export task 767NOYECETXX5BSPIBFM32DA for image 176 with label 1.
# 2024-09-26 05:51:02,330 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:51:35,708 - INFO - Started export task 7FPXVUW6VLBYQU27IV736TQB for image 177 with label 1.
# 2024-09-26 05:51:38,361 - INFO - Started export task DDI3Z5QNX2NMAEX52G6NFAWL for image 178 with label 1.
# 2024-09-26 05:51:41,382 - INFO - Started export task IPTBVDMK4FI3ICEZYEDRPJLI for image 179 with label 1.
# 2024-09-26 05:51:44,546 - INFO - Started export task L2UITNPF5N6UW7CU5WVEHDTY for image 180 with label 1.
# 2024-09-26 05:51:47,739 - INFO - Started export task 4RYJVV73PTGGO3ODOGFWV6GF for image 181 with label 1.
# 2024-09-26 05:51:47,909 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:52:20,754 - INFO - Started export task GZLIHISSS5RWJQGD4XVZSWG6 for image 182 with label 1.
# 2024-09-26 05:52:24,215 - INFO - Started export task N327YB6QO5Y3453ERSFTKD7N for image 183 with label 1.
# 2024-09-26 05:52:27,561 - INFO - Started export task 4TOX22IS632KQH52GNFWKB4N for image 184 with label 1.
# 2024-09-26 05:52:31,384 - INFO - Started export task SI6GS3XRIVKC2C7BDR3UZJE4 for image 185 with label 1.
# 2024-09-26 05:52:34,429 - INFO - Started export task IMYEVL7S5ZGUGNINX4KACF65 for image 186 with label 1.
# 2024-09-26 05:52:37,963 - INFO - Started export task NF33OY7XBG4AQWUS36ATRX2E for image 187 with label 1.
# 2024-09-26 05:52:41,230 - INFO - Started export task LZJJGODFGQOCCXNTYOXWRZ24 for image 188 with label 1.
# 2024-09-26 05:52:44,110 - INFO - Started export task VIAAODTUUNWUQIBTKB5UA3M5 for image 189 with label 1.
# 2024-09-26 05:52:48,818 - INFO - Started export task F4HF3I3L53VGF2M5TQIKO5C5 for image 190 with label 1.
# 2024-09-26 05:52:49,141 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:53:22,571 - INFO - Started export task 5VMPJMRUDQNGCO74AIKDHVBQ for image 191 with label 1.
# 2024-09-26 05:53:25,744 - INFO - Started export task 25WM2AJ72GZ7ALCYZ7GUT2KK for image 192 with label 1.
# 2024-09-26 05:53:28,788 - INFO - Started export task BUCB6V27NDLP7OISPQNJPIR4 for image 193 with label 1.
# 2024-09-26 05:53:32,399 - INFO - Started export task WNGSR57AI4CPJDPZYWO47FFK for image 194 with label 1.
# 2024-09-26 05:53:35,333 - INFO - Started export task P4E7RALJQG5G732CJQLZDF67 for image 195 with label 1.
# 2024-09-26 05:53:39,075 - INFO - Started export task SIAXIBVBTNSFJ3E2E7CU3AQ2 for image 196 with label 1.
# 2024-09-26 05:53:41,978 - INFO - Started export task 55TDXHAMIMCY2NGDZULQVJ7A for image 197 with label 1.
# 2024-09-26 05:53:45,370 - INFO - Started export task V5NID4E7GPQ5NV5H6VYPWFYN for image 198 with label 1.
# 2024-09-26 05:53:45,706 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:54:18,269 - INFO - Started export task BDOVPFFGJRMGUUX2QPZNBYXF for image 199 with label 1.
# 2024-09-26 05:54:21,720 - INFO - Started export task AFVMZL54RYV7UNHHAWRG2QCV for image 200 with label 1.
# 2024-09-26 05:54:24,981 - INFO - Started export task 36BBV7QFZ3D6SELQY2ALB6NM for image 201 with label 1.
# 2024-09-26 05:54:28,034 - INFO - Started export task ZDHE3W4ZGMTL4YTF6UVY3RWO for image 202 with label 1.
# 2024-09-26 05:54:31,165 - INFO - Started export task FCFRMNYXS44BTMF5LU7YRXUY for image 203 with label 1.
# 2024-09-26 05:54:35,070 - INFO - Started export task 3SVLAUFTZXR6VBHN3T7AY5RX for image 204 with label 1.
# 2024-09-26 05:54:38,646 - INFO - Started export task HVNWWG4UMYLOCLPY7N7FW3MB for image 205 with label 1.
# 2024-09-26 05:54:41,647 - INFO - Started export task OXB4Y2MFQ4GZUK2WVDUMSCHS for image 206 with label 1.
# 2024-09-26 05:54:44,906 - INFO - Started export task IKVPE7TNW6LFHPY7FUI2S3FQ for image 207 with label 1.
# 2024-09-26 05:54:47,976 - INFO - Started export task NITBGFICI3QQA5P45EJ6FWUO for image 208 with label 1.
# 2024-09-26 05:54:50,986 - INFO - Started export task GQDJVUQSBHFYO3UHHJW2HMXB for image 209 with label 1.
# 2024-09-26 05:54:51,198 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:55:24,857 - INFO - Started export task WLUXD3AWBQWMSABT3RFIB7XQ for image 210 with label 1.
# 2024-09-26 05:55:27,722 - INFO - Started export task NBNEWP3G4CPH22QV375KTVPF for image 211 with label 1.
# 2024-09-26 05:55:30,485 - INFO - Started export task TUEFMUKW6JYBY7AAHMOFSNUU for image 212 with label 1.
# 2024-09-26 05:55:33,906 - INFO - Started export task E3KD3YZJ66INHXKGCHDGCWAJ for image 213 with label 1.
# 2024-09-26 05:55:37,833 - INFO - Started export task A3KGHMEYQ4BI6EOMTV4FJQGF for image 214 with label 1.
# 2024-09-26 05:55:40,998 - INFO - Started export task EGWYOIUTIBWIU3DMGRBEAZI6 for image 215 with label 1.
# 2024-09-26 05:55:44,093 - INFO - Started export task ULGNLGMV3W43V3RYDR7LGBUO for image 216 with label 1.
# 2024-09-26 05:55:48,067 - INFO - Started export task TDGDEXFDGWRJJ3JMNEMNSN2R for image 217 with label 1.
# 2024-09-26 05:55:51,575 - INFO - Started export task L7VRK23STUGOERZ4FZE43YI2 for image 218 with label 1.
# 2024-09-26 05:55:54,738 - INFO - Started export task 5WIPVGNTMFICNWRDKPAMGGJ2 for image 219 with label 1.
# 2024-09-26 05:55:54,951 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:56:27,369 - INFO - Started export task 4DHPHK3RALML5WWEPZMIUWY2 for image 220 with label 1.
# 2024-09-26 05:56:30,236 - INFO - Started export task OYKJ7T42WYDFKQ526QAK7RNK for image 221 with label 1.
# 2024-09-26 05:56:32,262 - INFO - Started export task YTIRXUUH4MHO7JH4PLEHDO3C for image 222 with label 1.
# 2024-09-26 05:56:35,210 - INFO - Started export task PHUBW2FLQLWD2BRNLSOHDM4J for image 223 with label 1.
# 2024-09-26 05:56:38,286 - INFO - Started export task 7K3BDU6UFSXOFDWL4VHOPU7B for image 224 with label 1.
# 2024-09-26 05:56:41,379 - INFO - Started export task 3ZQ7ATZDKX35MMQBJQO6N72H for image 225 with label 1.
# 2024-09-26 05:56:44,772 - INFO - Started export task SQYJ2OGU323UIAYDJ4AKSWR4 for image 226 with label 1.
# 2024-09-26 05:56:45,003 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:57:18,578 - INFO - Started export task UHKZ56BT53BHKZLWL3XANDU4 for image 227 with label 1.
# 2024-09-26 05:57:21,295 - INFO - Started export task UBJNZSY62SLB7BEDPAI5PDV5 for image 228 with label 1.
# 2024-09-26 05:57:23,927 - INFO - Started export task UDS7WVXIAIZ7E37E2ZXBPS66 for image 229 with label 1.
# 2024-09-26 05:57:27,524 - INFO - Started export task GWV6XERZZBZQORNWMLSENCTT for image 230 with label 1.
# 2024-09-26 05:57:31,062 - INFO - Started export task HALFD5QTNOG7JXHKXZD4VL5P for image 231 with label 1.
# 2024-09-26 05:57:33,802 - INFO - Started export task 3YL46JJ2BNXXH3TTMQGMIF7B for image 232 with label 1.
# 2024-09-26 05:57:37,229 - INFO - Started export task YD3TFKAATOIRIDFYJCJWPU2J for image 233 with label 1.
# 2024-09-26 05:57:40,551 - INFO - Started export task XKKNCPPT7M65VH4CXCNHQYMX for image 234 with label 1.
# 2024-09-26 05:57:40,926 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:58:14,005 - INFO - Started export task 54YSQKRYH6DXXG3NDNI6RVEE for image 235 with label 1.
# 2024-09-26 05:58:17,415 - INFO - Started export task NVO6LOIPWBO47YV3NQVIAQB7 for image 236 with label 1.
# 2024-09-26 05:58:20,678 - INFO - Started export task YNSTKK6QDV7ZHGRNGEXBG3BV for image 237 with label 1.
# 2024-09-26 05:58:23,648 - INFO - Started export task E5B4GXERHTICYDD5S3ORPLFB for image 238 with label 1.
# 2024-09-26 05:58:26,737 - INFO - Started export task THKXXG7Q7MMVBWW4H5UWWEPN for image 239 with label 1.
# 2024-09-26 05:58:29,676 - INFO - Started export task 2QWHOBB7THMCIMHOKWC4NRRI for image 240 with label 1.
# 2024-09-26 05:58:33,449 - INFO - Started export task 354S62UOSI3Y4PD2QOKCQRKJ for image 241 with label 1.
# 2024-09-26 05:58:35,364 - INFO - Started export task FSMTPS4JGEAOQ3HVCVWHHB6Z for image 242 with label 1.
# 2024-09-26 05:58:35,566 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:59:08,390 - INFO - Started export task L2D4WJZ6OTWXR3KWYOITELXQ for image 243 with label 1.
# 2024-09-26 05:59:12,193 - INFO - Started export task QKSXTDWLM5W7XUSEL3HIS5YD for image 244 with label 1.
# 2024-09-26 05:59:16,088 - INFO - Started export task FH5NOYMBTZXGBZRZX76DTABW for image 245 with label 1.
# 2024-09-26 05:59:19,248 - INFO - Started export task BBMS7EATBNNPJTNEOEROGRR4 for image 246 with label 1.
# 2024-09-26 05:59:22,589 - INFO - Started export task ELGV6GGX2WKTB5WOX6XCCY76 for image 247 with label 1.
# 2024-09-26 05:59:25,489 - INFO - Started export task GJ6UN7JB4NF2FILELF4T6KTN for image 248 with label 1.
# 2024-09-26 05:59:25,692 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 05:59:57,863 - INFO - Started export task AMO6ZPNU3K46CH5KSNAQCF6X for image 249 with label 1.
# 2024-09-26 06:00:01,588 - INFO - Started export task CTGTWNDCQCDMK44PQP2A6CW4 for image 250 with label 1.
# 2024-09-26 06:00:05,108 - INFO - Started export task J4PKM4UIX4WCK4VJMZREKZI4 for image 251 with label 1.
# 2024-09-26 06:00:09,675 - INFO - Started export task FZNNUOZHVGAW3KI2FYPP4BC2 for image 252 with label 1.
# 2024-09-26 06:00:09,917 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:00:43,609 - INFO - Started export task BTBUSWWIEND6HPU47CKWOWMV for image 253 with label 1.
# 2024-09-26 06:00:47,208 - INFO - Started export task IQ4ZKXDIES2SFPEPL6Z66X7W for image 254 with label 1.
# 2024-09-26 06:00:50,439 - INFO - Started export task CWEBAI7H77PLYCMRODH7PA2P for image 255 with label 1.
# 2024-09-26 06:00:54,672 - INFO - Started export task FQVD7GCMJ5ZHZFPPUUVUB7Q3 for image 256 with label 1.
# 2024-09-26 06:00:57,532 - INFO - Started export task D3CK2SPFCVFNLI7NSPPHZ6LA for image 257 with label 1.
# 2024-09-26 06:01:00,662 - INFO - Started export task MABSH42UP6O47OLLNNYGACLH for image 258 with label 1.
# 2024-09-26 06:01:03,976 - INFO - Started export task GCHRHWNGATMJ6MDRGTVELI3O for image 259 with label 1.
# 2024-09-26 06:01:07,406 - INFO - Started export task OXZ237OXPLXWRJN7BEOSZLEB for image 260 with label 1.
# 2024-09-26 06:01:07,743 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:01:42,095 - INFO - Started export task PIPEXBKG23EV5SNPIKPPHM2P for image 261 with label 1.
# 2024-09-26 06:01:46,008 - INFO - Started export task 3NIEYZR7A72HPA3O5PUCDON5 for image 262 with label 1.
# 2024-09-26 06:01:48,988 - INFO - Started export task MFMEZUYACSSJVF5LUZ32IOJI for image 263 with label 1.
# 2024-09-26 06:01:52,391 - INFO - Started export task 3INKRMMAX3MWNH32JQHJP6XV for image 264 with label 1.
# 2024-09-26 06:01:55,754 - INFO - Started export task CCBSBOZ4VSQ5GI7YB27MCW7H for image 265 with label 1.
# 2024-09-26 06:01:58,607 - INFO - Started export task PMWXSAJYOZ4SZSRPD27OQL3K for image 266 with label 1.
# 2024-09-26 06:02:00,768 - INFO - Started export task 5J3UDIFWQYASKHVLDRXZ3QNV for image 267 with label 1.
# 2024-09-26 06:02:03,910 - INFO - Started export task ZJCJKE5CJBHHBZQIDETYXUCI for image 268 with label 1.
# 2024-09-26 06:02:07,046 - INFO - Started export task MWAUKEVKGEN3WHUJAEAKOMOM for image 269 with label 1.
# 2024-09-26 06:02:10,410 - INFO - Started export task KFVLS7E3EX4VK7RZRV6XQHY4 for image 270 with label 1.
# 2024-09-26 06:02:10,739 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:02:43,668 - INFO - Started export task KHM6Y3WGIM74SSJ4536MJZ36 for image 271 with label 1.
# 2024-09-26 06:02:46,773 - INFO - Started export task RHVCH5OQHZBK2R3U7RMIUQDK for image 272 with label 1.
# 2024-09-26 06:02:49,539 - INFO - Started export task KWRXO3DIGGP2CDB3PIZEXETE for image 273 with label 1.
# 2024-09-26 06:02:53,284 - INFO - Started export task KYRG4L2MRXSGFPYPZEQDDU3K for image 274 with label 1.
# 2024-09-26 06:02:53,525 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:03:26,833 - INFO - Started export task 5H4IXNIAMLPB3M7QWYTWPS4D for image 275 with label 1.
# 2024-09-26 06:03:28,971 - INFO - Started export task DSND73THWZRPVU2FDHEP5FJJ for image 276 with label 1.
# 2024-09-26 06:03:32,555 - INFO - Started export task SLC4TUZ7LNORH4S6H2B2FDFQ for image 277 with label 1.
# 2024-09-26 06:03:36,036 - INFO - Started export task HGFER66GGHAPXZVEVPN2QJYM for image 278 with label 1.
# 2024-09-26 06:03:39,198 - INFO - Started export task 6MJ4IQQLRYIZWPGHTJQMSWQL for image 279 with label 1.
# 2024-09-26 06:03:42,196 - INFO - Started export task CTOHEYI2DDB2RJSOOHMUHMUT for image 280 with label 1.
# 2024-09-26 06:03:45,626 - INFO - Started export task KUPEDMONXLP4DSMJ34ZABXNB for image 281 with label 1.
# 2024-09-26 06:03:45,945 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:04:19,021 - INFO - Started export task HU4Q7UR6D3FE7YXTXZ3V3LFD for image 282 with label 1.
# 2024-09-26 06:04:22,146 - INFO - Started export task PV3MD6M5YTQXDMXS3AD4U6BO for image 283 with label 1.
# 2024-09-26 06:04:26,187 - INFO - Started export task T26IIONFVREUFNHZRQ4CL2FA for image 284 with label 1.
# 2024-09-26 06:04:29,429 - INFO - Started export task 5UFAKNYUMSSQ5H7SQWWN3F6K for image 285 with label 1.
# 2024-09-26 06:04:32,684 - INFO - Started export task R5V6ECYA4W6Z62YI4TP4OMS6 for image 286 with label 1.
# 2024-09-26 06:04:36,236 - INFO - Started export task O25WIMUHHQLYDDUB7P4F6VQR for image 287 with label 1.
# 2024-09-26 06:04:39,376 - INFO - Started export task VDDDPSAFW3R4RYH43KV3EHY5 for image 288 with label 1.
# 2024-09-26 06:04:42,800 - INFO - Started export task 6Y33RQ235HXHCY5IGCZEZJS7 for image 289 with label 1.
# 2024-09-26 06:04:45,987 - INFO - Started export task 463S3L2ORTKPGCKXF3Q2GKGX for image 290 with label 1.
# 2024-09-26 06:04:49,002 - INFO - Started export task PKMPUFIZKXULG6WQ6CGLRBGW for image 291 with label 1.
# 2024-09-26 06:04:52,757 - INFO - Started export task 4DTKHTDBV7ZCI6FEACC4AFR7 for image 292 with label 1.
# 2024-09-26 06:04:52,969 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:05:26,499 - INFO - Started export task 3VDW5S24S3V4ISFSOHXG5X5O for image 293 with label 1.
# 2024-09-26 06:05:29,125 - INFO - Started export task EP6K34HK7BG2QJVUC2B773TQ for image 294 with label 1.
# 2024-09-26 06:05:32,571 - INFO - Started export task ECALHO22TDN44YP7UKGMHCIW for image 295 with label 1.
# 2024-09-26 06:05:36,851 - INFO - Started export task PIRDBZIRBIVJZQPBTIDQ4YCL for image 296 with label 1.
# 2024-09-26 06:05:39,474 - INFO - Started export task XLK5CWNABP7PGNLCWHZ7NOQK for image 297 with label 1.
# 2024-09-26 06:05:42,827 - INFO - Started export task CMYW7RXU4RF5NN7DM3SDE4PQ for image 298 with label 1.
# 2024-09-26 06:05:43,082 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:06:16,844 - INFO - Started export task LICKGGCTNA57YUEQL7XHGEPX for image 299 with label 1.
# 2024-09-26 06:06:20,293 - INFO - Started export task V6IJGT4PIX32AV6OZMUB6BQK for image 300 with label 1.
# 2024-09-26 06:06:24,196 - INFO - Started export task KSPPSCH4RG46VYLLGPV2RBPR for image 301 with label 1.
# 2024-09-26 06:06:27,065 - INFO - Started export task 336HXUNUI6NO3JZD4AWCS63I for image 302 with label 1.
# 2024-09-26 06:06:30,009 - INFO - Started export task 5ZTOKXWFHUWNXXHLQDOQZ56T for image 303 with label 1.
# 2024-09-26 06:06:32,845 - INFO - Started export task 5CFDL2VUUXEJI2T2DSDZIVH5 for image 304 with label 1.
# 2024-09-26 06:06:35,795 - INFO - Started export task ZHCKSFKZO73CZ7K4E3SL3UOC for image 305 with label 1.
# 2024-09-26 06:06:35,975 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:07:09,378 - INFO - Started export task 2EWAAV4WFNY4R4UBXIEHWC5G for image 306 with label 1.
# 2024-09-26 06:07:13,774 - INFO - Started export task NWEBGOZJ5FLSOCCODHRNFFCT for image 307 with label 1.
# 2024-09-26 06:07:17,142 - INFO - Started export task TFL4NYXCAT6AEVIID3FUQ2UI for image 308 with label 1.
# 2024-09-26 06:07:20,169 - INFO - Started export task ASEOSBV5RP7NDRBGVUUOQ2UX for image 309 with label 1.
# 2024-09-26 06:07:23,164 - INFO - Started export task L43JZNA7FZIYFSN26WS7NKD4 for image 310 with label 1.
# 2024-09-26 06:07:26,040 - INFO - Started export task LCONELRACUWOUQC4UIS6T3TJ for image 311 with label 1.
# 2024-09-26 06:07:26,399 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:07:59,579 - INFO - Started export task TTX63OEOWXKKOKMMCZUBMYHD for image 312 with label 1.
# 2024-09-26 06:08:03,200 - INFO - Started export task 2276UJFJYJOH5S76NNHANUUL for image 313 with label 1.
# 2024-09-26 06:08:06,693 - INFO - Started export task CE2RTZFT4LC75DKQ3SHDUX5B for image 314 with label 1.
# 2024-09-26 06:08:10,098 - INFO - Started export task ILRMUIKG7XE5ASLVCU7A4DSA for image 315 with label 1.
# 2024-09-26 06:08:13,152 - INFO - Started export task E4YTQBETU5ZVRR573YSSIFVN for image 316 with label 1.
# 2024-09-26 06:08:16,486 - INFO - Started export task ITKTEYDTJ5SSYU3M4C6JEMIO for image 317 with label 1.
# 2024-09-26 06:08:20,670 - INFO - Started export task 66QY5H5TEZP3EZUMKOIRPETF for image 318 with label 1.
# 2024-09-26 06:08:20,994 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:08:53,611 - INFO - Started export task UOR7ISUT6LNB3C626SKMAMXU for image 319 with label 1.
# 2024-09-26 06:08:56,654 - INFO - Started export task UGH7PF3A5VBR6RLK2GCB4HVD for image 320 with label 1.
# 2024-09-26 06:08:59,805 - INFO - Started export task Z33KLMRIIMZDVFNZGG5FGAL6 for image 321 with label 1.
# 2024-09-26 06:09:03,310 - INFO - Started export task MDBF5WRH5CNCZJPQUOYZFYVD for image 322 with label 1.
# 2024-09-26 06:09:06,797 - INFO - Started export task C5SDNKCYSLSUCVBKUN7OVTMI for image 323 with label 1.
# 2024-09-26 06:09:10,242 - INFO - Started export task OU2BSLUYU6FFT5UAEOWJJK4T for image 324 with label 1.
# 2024-09-26 06:09:10,423 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:09:44,134 - INFO - Started export task XXAMNSLBDNYAUYLKL5UAFHOV for image 325 with label 1.
# 2024-09-26 06:09:48,177 - INFO - Started export task NT4B5TSVNBXHW7WTUB4ITOXZ for image 326 with label 1.
# 2024-09-26 06:09:51,602 - INFO - Started export task 7V7FZVCPVJUUAIRIIQWJEOSG for image 327 with label 1.
# 2024-09-26 06:09:54,571 - INFO - Started export task EVF6UINZJ2GDVB5LZFWPO2XO for image 328 with label 1.
# 2024-09-26 06:09:58,823 - INFO - Started export task JUZFU5SGMO6UC5T4KKDDMUJ2 for image 329 with label 1.
# 2024-09-26 06:10:01,729 - INFO - Started export task N55HYOMQS64AIPAAU4FNEKHY for image 330 with label 1.
# 2024-09-26 06:10:05,320 - INFO - Started export task QRPVZLB2ZWJO4PSPOACR56YT for image 331 with label 1.
# 2024-09-26 06:10:05,645 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:10:39,127 - INFO - Started export task U4EIZ7B2WFHI6ABPRNS42ME2 for image 332 with label 1.
# 2024-09-26 06:10:41,869 - INFO - Started export task 3UKRZO4EPAHHPT3MAB2SJKPS for image 333 with label 1.
# 2024-09-26 06:10:44,974 - INFO - Started export task AJ2UH4KLD3TQIZI6CVDT4X2R for image 334 with label 1.
# 2024-09-26 06:10:48,574 - INFO - Started export task RGVLWUBSJY4IXA6D5MENQ2CD for image 335 with label 1.
# 2024-09-26 06:10:51,980 - INFO - Started export task 5GH74F6JRGDGIGZUFGFOVBT2 for image 336 with label 1.
# 2024-09-26 06:10:52,235 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:11:26,059 - INFO - Started export task ULT4OF4DMKJN5ZVSSL6TZ6XO for image 337 with label 1.
# 2024-09-26 06:11:29,053 - INFO - Started export task QWVNUG7YUN6YQVA4XYSFXM47 for image 338 with label 1.
# 2024-09-26 06:11:31,658 - INFO - Started export task 2ISRSAUB6W4IXL64VFGWWCDH for image 339 with label 1.
# 2024-09-26 06:11:34,924 - INFO - Started export task OKWRTUCCHBM66UQG7WMIPAKN for image 340 with label 1.
# 2024-09-26 06:11:37,500 - INFO - Started export task Q4DCDIDY6JR4WO4PPDQHEB4A for image 341 with label 1.
# 2024-09-26 06:11:37,725 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:12:11,446 - INFO - Started export task B23ZHBJSGMUAX7S7KPJD6CM4 for image 342 with label 1.
# 2024-09-26 06:12:14,186 - INFO - Started export task 6EH7NFVBSFY3TUCOPP6QWPR3 for image 343 with label 1.
# 2024-09-26 06:12:17,832 - INFO - Started export task NPJMQH74TSLV6MGRBYSJ6G3X for image 344 with label 1.
# 2024-09-26 06:12:20,136 - INFO - Started export task QHPXQK5B3FHQBUCITN5PRMCW for image 345 with label 1.
# 2024-09-26 06:12:20,350 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:12:53,950 - INFO - Started export task 2IIRU5AOCUOL2YZOQVFDAC7H for image 346 with label 1.
# 2024-09-26 06:12:57,274 - INFO - Started export task PG6KHG66CXHPCQ4ZRJAY77WE for image 347 with label 1.
# 2024-09-26 06:13:00,924 - INFO - Started export task XAPTV34NXS3EL4P47OYASZV3 for image 348 with label 1.
# 2024-09-26 06:13:05,137 - INFO - Started export task 6IDMU7VBRFQMXRLXZNO46OI7 for image 349 with label 1.
# 2024-09-26 06:13:05,411 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:13:38,664 - INFO - Started export task CMG4G7ZZBA6QZBSFB2PGGGET for image 350 with label 1.
# 2024-09-26 06:13:42,595 - INFO - Started export task IJPWRMUZN7MZ5EA77EFW7J3O for image 351 with label 1.
# 2024-09-26 06:13:45,986 - INFO - Started export task VUM7OH6MMQACUCXFZTV2SZ5J for image 352 with label 1.
# 2024-09-26 06:13:49,061 - INFO - Started export task NJLS2IHG2GWLGISQ5AJL7UVD for image 353 with label 1.
# 2024-09-26 06:13:52,579 - INFO - Started export task VEOK4DH6REZDRRYZBAXXFP46 for image 354 with label 1.
# 2024-09-26 06:13:55,224 - INFO - Started export task 75KTQK3ZBTD5UIDDJVDEJLSK for image 355 with label 1.
# 2024-09-26 06:13:55,459 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:14:28,813 - INFO - Started export task JMMRGDRRCVNICHLRT5B62JFL for image 356 with label 1.
# 2024-09-26 06:14:31,744 - INFO - Started export task NVS4QTX3W4TPDY4WKTXV3HAS for image 357 with label 1.
# 2024-09-26 06:14:34,339 - INFO - Started export task X3UUPGHFGM6UYTVHBMSPZGJV for image 358 with label 1.
# 2024-09-26 06:14:37,773 - INFO - Started export task NJJYQILPW7TSD3Q3EBVBZXKO for image 359 with label 1.
# 2024-09-26 06:14:41,341 - INFO - Started export task BTWCDV7VHQ2L4IVR3VWMW7PW for image 360 with label 1.
# 2024-09-26 06:14:41,663 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:15:14,798 - INFO - Started export task IVSZBGLWFJTCMUPTMHQWZHD6 for image 361 with label 1.
# 2024-09-26 06:15:17,854 - INFO - Started export task 4VIIHZBIZ5ZISKGBH4BPYMHP for image 362 with label 1.
# 2024-09-26 06:15:21,633 - INFO - Started export task 5T3WQ4N4JI6JC27FB33OIEGS for image 363 with label 1.
# 2024-09-26 06:15:24,880 - INFO - Started export task DZZSLY6HP7XDGNOL43AEDELL for image 364 with label 1.
# 2024-09-26 06:15:28,218 - INFO - Started export task JNXGQSAKKRV3ZEENWYHM3VNL for image 365 with label 1.
# 2024-09-26 06:15:32,225 - INFO - Started export task FUU37WRAJDR4EI5NEDSWWOHB for image 366 with label 1.
# 2024-09-26 06:15:32,544 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:16:04,712 - INFO - Started export task 7DLJZBPQXFKT7URAJT3A2H75 for image 367 with label 1.
# 2024-09-26 06:16:07,876 - INFO - Started export task 5QUIP5CMGKS7AL6X32USJ3SX for image 368 with label 1.
# 2024-09-26 06:16:10,991 - INFO - Started export task F7RGIU6HIRSDMSFTSF54QXX6 for image 369 with label 1.
# 2024-09-26 06:16:14,254 - INFO - Started export task LZQCEYP2T4RJGTBZ3XJS5GWF for image 370 with label 1.
# 2024-09-26 06:16:17,565 - INFO - Started export task VRXGIYTGDD5KCKCOPMCIC4KS for image 371 with label 1.
# 2024-09-26 06:16:20,515 - INFO - Started export task VUHSDOU57GNA7OWVHZDX5UJJ for image 372 with label 1.
# 2024-09-26 06:16:23,788 - INFO - Started export task VY7DMTZPJ6EJMI7PLFZJVFDS for image 373 with label 1.
# 2024-09-26 06:16:23,980 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:16:58,942 - INFO - Started export task WNQUW6LXHD7SUSEYEV4E6TWV for image 374 with label 1.
# 2024-09-26 06:17:02,622 - INFO - Started export task JJPWMX7KWE26UTHDUXFBBB6C for image 375 with label 1.
# 2024-09-26 06:17:05,460 - INFO - Started export task R25L62Q6N7SNS2CTHB47DENJ for image 376 with label 1.
# 2024-09-26 06:17:09,009 - INFO - Started export task UAFPKZF6ICHVKOJMIPLDFXW3 for image 377 with label 1.
# 2024-09-26 06:17:12,567 - INFO - Started export task P7EO2PEMXE4RUDUT7Q66AG2K for image 378 with label 1.
# 2024-09-26 06:17:16,540 - INFO - Started export task NQOA6VVL35COSTTSS3GTJFQW for image 379 with label 1.
# 2024-09-26 06:17:16,884 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:17:49,045 - INFO - Started export task P4HLWNQTIFMXNLF2LH2XCU6K for image 380 with label 1.
# 2024-09-26 06:17:51,845 - INFO - Started export task VPSYTLT3QXFES3KHFDOHISQK for image 381 with label 1.
# 2024-09-26 06:17:55,290 - INFO - Started export task BB6XKPWNSGJTZ3HAFQIJX7FL for image 382 with label 1.
# 2024-09-26 06:17:57,824 - INFO - Started export task S2YBJXSEUHT3F3V2H6JYPILO for image 383 with label 1.
# 2024-09-26 06:17:58,023 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:18:30,868 - INFO - Started export task 7P3AUVKJNZS4EPYZBWXXK6KJ for image 384 with label 1.
# 2024-09-26 06:18:34,242 - INFO - Started export task FJM5ELAQUSR2WE6JZQETTYSR for image 385 with label 1.
# 2024-09-26 06:18:37,477 - INFO - Started export task GU4XGG6OZSTL4QN43VN6CE2S for image 386 with label 1.
# 2024-09-26 06:18:40,627 - INFO - Started export task YWXFUJOVVIK3ZOGYT7BHVCEM for image 387 with label 1.
# 2024-09-26 06:18:43,628 - INFO - Started export task F5AIIWW7PVVVLSHFPR235CNM for image 388 with label 1.
# 2024-09-26 06:18:43,958 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:19:17,284 - INFO - Started export task USCOIMKW5A4VWELROQPXZLEK for image 389 with label 1.
# 2024-09-26 06:19:20,457 - INFO - Started export task CQYIK5QFL6RDW3XDNOLBRYKR for image 390 with label 1.
# 2024-09-26 06:19:24,469 - INFO - Started export task VQ6DKN4XNUF2YR7E4JSYSTR2 for image 391 with label 1.
# 2024-09-26 06:19:24,681 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 06:19:57,611 - INFO - Started export task S7BIWLL6DNOA3IVUMK26DWOX for image 392 with label 1.
# ...
# 2024-09-26 07:54:36,120 - INFO - Started export task DUU2WBBP7VBNQHPYGKY7EALX for image 918 with label 0.
# 2024-09-26 07:54:39,676 - INFO - Started export task BFQASJAOQ4X43F6Q62FGXFEL for image 919 with label 0.
# 2024-09-26 07:54:43,343 - INFO - Started export task RIBQCY765PXU35Z7HIT44QO4 for image 920 with label 0.
# 2024-09-26 07:54:47,517 - INFO - Started export task K2526YET4ZBEQPMOWSSTM6CV for image 921 with label 0.
# 2024-09-26 07:54:50,780 - INFO - Started export task VETO43LWKJH7RPVQOZRG5HU2 for image 922 with label 0.
# 2024-09-26 07:54:54,311 - INFO - Started export task LQF3ZNQF3YXGHTZG6MNDJPAZ for image 923 with label 0.
# 2024-09-26 07:54:58,062 - INFO - Started export task S23JETFISPCGILCT7YE4H4D5 for image 924 with label 0.
# 2024-09-26 07:54:58,657 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 07:55:32,371 - INFO - Started export task HPUEUOJMVNSDLVUMYJOQDVON for image 925 with label 0.
# 2024-09-26 07:55:36,102 - INFO - Started export task M3TQ46H5B4BXAGPKBJ46KWON for image 926 with label 0.
# 2024-09-26 07:55:39,314 - INFO - Started export task PFICAPTCGR7LCGXKG24E46IT for image 927 with label 0.
# 2024-09-26 07:55:42,837 - INFO - Started export task NL3BFNSEZ6CRYFEKRPYBYK4V for image 928 with label 0.
# 2024-09-26 07:55:46,874 - INFO - Started export task ZE2YAM6B5Y5VPI4CTTQ3PPJP for image 929 with label 0.
# 2024-09-26 07:55:47,708 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 07:56:21,650 - INFO - Started export task CJ4FFAA2ZDIK5CAQFSOFHDRU for image 930 with label 0.
# 2024-09-26 07:56:25,689 - INFO - Started export task VCYTJQJTGYXELGDWHQ2FP4LN for image 931 with label 0.
# 2024-09-26 07:56:29,264 - INFO - Started export task BQYGC5BLPFDTEGGI4MXURMGO for image 932 with label 0.
# 2024-09-26 07:56:33,139 - INFO - Started export task EL3SIATCQFOZPSJVB33BVIMT for image 933 with label 0.
# 2024-09-26 07:56:33,704 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 07:57:07,364 - INFO - Started export task NM5B4SDHCU6Z2SC3BKA6EQKA for image 934 with label 0.
# 2024-09-26 07:57:11,559 - INFO - Started export task 4BLKZR3S4FEYVFCVFNZ3YIAI for image 935 with label 0.
# 2024-09-26 07:57:14,586 - INFO - Started export task VVDPMPCB5TT77YFNBEEC53PI for image 936 with label 0.
# 2024-09-26 07:57:18,278 - INFO - Started export task XGYLKRXZPMI5Y6UVXY6C35E6 for image 937 with label 0.
# 2024-09-26 07:57:22,561 - INFO - Started export task G3FPUZBXBI2SBJP7CG4FYSS5 for image 938 with label 0.
# 2024-09-26 07:57:23,158 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 07:57:57,107 - INFO - Started export task D5YN5JMMJUCVIZNRPT27F24M for image 939 with label 0.
# 2024-09-26 07:58:00,182 - INFO - Started export task SDC5CUVR3LKPDBL42HGJJSGQ for image 940 with label 0.
# 2024-09-26 07:58:03,506 - INFO - Started export task QSP3OYOX5FJKKQLVYBU6RDTW for image 941 with label 0.
# 2024-09-26 07:58:07,862 - INFO - Started export task UOXID2QBXMJ4COIKOU62R7PW for image 942 with label 0.
# 2024-09-26 07:58:08,405 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 07:58:43,807 - INFO - Started export task MZPBK36K4CAX3BHTNHQJUTCO for image 943 with label 0.
# 2024-09-26 07:58:47,925 - INFO - Started export task QXOHZGQK6RWZDXFTFOZQF5JW for image 944 with label 0.
# 2024-09-26 07:58:51,063 - INFO - Started export task WM74QYORB22HW6PGOJG66UGG for image 945 with label 0.
# 2024-09-26 07:58:54,590 - INFO - Started export task JUD4JR3YDUMQMPR54NH22PZE for image 946 with label 0.
# 2024-09-26 07:58:58,027 - INFO - Started export task AZBIDLU3YDCQOTSME4OTCUY6 for image 947 with label 0.
# 2024-09-26 07:59:01,650 - INFO - Started export task PXLHX2N662CIPRZN4XR4VPQF for image 948 with label 0.
# 2024-09-26 07:59:02,182 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 07:59:36,147 - INFO - Started export task NMC75LAYNHRE7VIOSRM24XN2 for image 949 with label 0.
# 2024-09-26 07:59:39,975 - INFO - Started export task GZH6EEOQQG3F34I4V4IO4CO4 for image 950 with label 0.
# 2024-09-26 07:59:43,726 - INFO - Started export task X76N2J2JQD6ODTLVDSMJGVWI for image 951 with label 0.
# 2024-09-26 07:59:46,151 - INFO - Started export task W2ICDCUDE667ZA3TKWUM3LM4 for image 952 with label 0.
# 2024-09-26 07:59:46,647 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 08:00:19,778 - INFO - Started export task ALP2PYROFSINPC7ZTX6XYGDW for image 953 with label 0.
# 2024-09-26 08:00:23,233 - INFO - Started export task 2KB6LHZJS7KQKPTPAXTZQQQQ for image 954 with label 0.
# 2024-09-26 08:00:27,343 - INFO - Started export task BHR54ZZDQOTQUDKRTSIG5FRX for image 955 with label 0.
# 2024-09-26 08:00:27,945 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 08:01:02,363 - INFO - Started export task PT4GTQZLWTZ6PN2FII5E2CPB for image 956 with label 0.
# 2024-09-26 08:01:06,430 - INFO - Started export task 2XGMISE47PCGKXLAOEEL5SDW for image 957 with label 0.
# 2024-09-26 08:01:10,095 - INFO - Started export task PXA5L6MVZYFC3K5CF5DYFZD3 for image 958 with label 0.
# 2024-09-26 08:01:13,412 - INFO - Started export task J5UVBDKCKZLR5QM7IIOMOUKL for image 959 with label 0.
# 2024-09-26 08:01:14,097 - INFO - Maximum active tasks reached. Waiting before starting new tasks...
# 2024-09-26 08:01:48,363 - INFO - Started export task T7DCAKI6B2J64VJJOAFZPSOM for image 960 with label 0.
# 2024-09-26 08:01:52,455 - INFO - Started export task EAHCSBNY64JTMONE7CZCEEXH for image 961 with label 0.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 119
#     116 logging.info(f'Started export task {task.id} for image {i} with label {label}.')
#     118 # Wait if maximum active tasks are reached
# --> 119 while get_num_active_tasks() >= MAX_ACTIVE_TASKS:
#     120     logging.info('Maximum active tasks reached. Waiting before starting new tasks...')
#     121     time.sleep(30)
#
# Cell In[12], line 90, in get_num_active_tasks()
#      89 def get_num_active_tasks():
# ---> 90     task_list = ee.data.getTaskList()
#      91     active_tasks = [task for task in task_list if task['state'] in ['READY', 'RUNNING']]
#      92     return len(active_tasks)
#
# File ~/.python/current/lib/python3.12/site-packages/ee/deprecation.py:44, in Deprecated.<locals>.Decorator.<locals>.Wrapper(*args, **kwargs)
#      36 @functools.wraps(func)
#      37 def Wrapper(*args, **kwargs):
#      38   warnings.warn_explicit(
#      39       '%s() is deprecated: %s' % (func.__name__, message),
#      40       category=DeprecationWarning,
#      41       filename=func.__code__.co_filename,
#      42       lineno=func.__code__.co_firstlineno + 1,
#      43   )
# ---> 44   return func(*args, **kwargs)
#
# File ~/.python/current/lib/python3.12/site-packages/ee/data.py:1647, in getTaskList()
#    1637 @deprecation.Deprecated('Use listOperations')
#    1638 def getTaskList() -> List[Any]:
#    1639   """Retrieves a list of the user's tasks.
#    1640
#    1641   Returns:
#    (...)
#    1644     canceled or failed tasks.
#    1645   """
#    1646   return [_cloud_api_utils.convert_operation_to_task(o)
# -> 1647           for o in listOperations()]
#
# File ~/.python/current/lib/python3.12/site-packages/ee/data.py:1670, in listOperations(project)
#    1664 request = (
#    1665     _get_cloud_projects()
#    1666     .operations()
#    1667     .list(pageSize=_TASKLIST_PAGE_SIZE, name=project)
#    1668 )
#    1669 while request is not None:
# -> 1670   response = _execute_cloud_call(request)
#    1671   operations += response.get('operations', [])
#    1672   request = _get_cloud_projects().operations().list_next(request, response)
#
# File ~/.python/current/lib/python3.12/site-packages/ee/data.py:406, in _execute_cloud_call(call, num_retries)
#     404 num_retries = _max_retries if num_retries is None else num_retries
#     405 try:
# --> 406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
#     408   raise _translate_cloud_exception(e)
#
# File ~/.python/current/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/.python/current/lib/python3.12/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File ~/.python/current/lib/python3.12/site-packages/googleapiclient/http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File ~/.python/current/lib/python3.12/site-packages/google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File ~/.python/current/lib/python3.12/site-packages/ee/_cloud_api_utils.py:70, in _Http.request(***failed resolving arguments***)
#      63 del redirections  # Ignored
#      65 try:
#      66   # googleapiclient is expecting an httplib2 object, and doesn't include
#      67   # requests error in the list of transient errors. Therefore, transient
#      68   # requests errors should be converted to kinds that googleapiclient
#      69   # consider transient.
# ---> 70   response = self._session.request(
#      71       method, uri, data=body, headers=headers, timeout=self._timeout
#      72   )
#      73 except requests.exceptions.ConnectionError as connection_error:
#      74   raise ConnectionError(connection_error) from connection_error
#
# File ~/.local/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/.python/current/lib/python3.12/http/client.py:1419, in HTTPConnection.getresponse(self)
#    1417 try:
#    1418     try:
# -> 1419         response.begin()
#    1420     except ConnectionError:
#    1421         self.close()
#
# File ~/.python/current/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/.python/current/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/.python/current/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/.python/current/lib/python3.12/ssl.py:1253, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249     if flags != 0:
#    1250         raise ValueError(
#    1251           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1252           self.__class__)
# -> 1253     return self.read(nbytes, buffer)
#    1254 else:
#    1255     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.python/current/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:
